# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 597

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
base_url = "http://api.openweathermap.org/data/2.5/weather?"
parameter_1 = 'q='
parameter_2 = '&appid='
#url = f"{base_url}{parameter_1}{query}{parameter_2}{weather_api_key}"
#print (url)#

# %%
# Define an empty list to fetch the weather data for each city
city_data = []
units = "Metric"
parameter_3 = '&units='

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{base_url}{parameter_1}{city}{parameter_2}{weather_api_key}{parameter_3}{units}"
    print (city_url)
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
    
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"] 
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?q=bagotville&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 1 of Set 1 | bagotville
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 2 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=port alfred&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 3 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?q=marv dasht&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 4 of Set 1 | marv dasht
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=albany&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 5 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?q=upornaya&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 6 of Set 1 | upornaya
# http://api.openweathermap.org/data/2.5/weather?q=norman wells&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 7 of Set 1 | norman wells
# http://api.openweathermap.org/data/2.5/weather?q=punta arenas&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 8 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=fuyang&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 9 of Set 1 | fuyang
# http://api.openweathermap.org/data/2.5/weather?q=cape town&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 10 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?q=kapaa&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 11 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?q=faanui&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 12 of Set 1 | faanui
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 13 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?q=khatanga&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 14 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?q=klaksvik&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 15 of Set 1 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?q=amderma&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 16 of Set 1 | amderma
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=bilibino&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 17 of Set 1 | bilibino
# http://api.openweathermap.org/data/2.5/weather?q=grand river south east&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 18 of Set 1 | grand river south east
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=sao felix do xingu&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 19 of Set 1 | sao felix do xingu
# http://api.openweathermap.org/data/2.5/weather?q=spencer&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 20 of Set 1 | spencer
# http://api.openweathermap.org/data/2.5/weather?q=dubai&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 21 of Set 1 | dubai
# http://api.openweathermap.org/data/2.5/weather?q=georgetown&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 22 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?q=palabuhanratu&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 23 of Set 1 | palabuhanratu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=nizhneyansk&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 24 of Set 1 | nizhneyansk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=elat&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 25 of Set 1 | elat
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 26 of Set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 27 of Set 1 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?q=agadez&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 28 of Set 1 | agadez
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 29 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=hamilton&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 30 of Set 1 | hamilton
# http://api.openweathermap.org/data/2.5/weather?q=mataura&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 31 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?q=ndende&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 32 of Set 1 | ndende
# http://api.openweathermap.org/data/2.5/weather?q=vaini&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 33 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?q=mandalgovi&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 34 of Set 1 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 35 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?q=tiarei&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 36 of Set 1 | tiarei
# http://api.openweathermap.org/data/2.5/weather?q=bluff&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 37 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?q=hilo&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 38 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?q=cancun&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 39 of Set 1 | cancun
# http://api.openweathermap.org/data/2.5/weather?q=kutum&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 40 of Set 1 | kutum
# http://api.openweathermap.org/data/2.5/weather?q=isangel&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 41 of Set 1 | isangel
# http://api.openweathermap.org/data/2.5/weather?q=east london&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 42 of Set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?q=yulara&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 43 of Set 1 | yulara
# http://api.openweathermap.org/data/2.5/weather?q=lorengau&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 44 of Set 1 | lorengau
# http://api.openweathermap.org/data/2.5/weather?q=ponta do sol&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 45 of Set 1 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?q=nieuw amsterdam&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 46 of Set 1 | nieuw amsterdam
# http://api.openweathermap.org/data/2.5/weather?q=sidney&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 47 of Set 1 | sidney
# http://api.openweathermap.org/data/2.5/weather?q=vaitupu&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 48 of Set 1 | vaitupu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=dalvik&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 49 of Set 1 | dalvik
# http://api.openweathermap.org/data/2.5/weather?q=attawapiskat&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 50 of Set 1 | attawapiskat
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=busselton&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 0 of Set 2 | busselton
# http://api.openweathermap.org/data/2.5/weather?q=zyryanka&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 1 of Set 2 | zyryanka
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 2 of Set 2 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=pokosnoye&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 3 of Set 2 | pokosnoye
# http://api.openweathermap.org/data/2.5/weather?q=belushya guba&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 4 of Set 2 | belushya guba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=waipawa&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 5 of Set 2 | waipawa
# http://api.openweathermap.org/data/2.5/weather?q=katsuura&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 6 of Set 2 | katsuura
# http://api.openweathermap.org/data/2.5/weather?q=bukachacha&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 7 of Set 2 | bukachacha
# http://api.openweathermap.org/data/2.5/weather?q=mys shmidta&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 8 of Set 2 | mys shmidta
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=lebu&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 9 of Set 2 | lebu
# http://api.openweathermap.org/data/2.5/weather?q=fortuna&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 10 of Set 2 | fortuna
# http://api.openweathermap.org/data/2.5/weather?q=bengkulu&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 11 of Set 2 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?q=saint-philippe&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 12 of Set 2 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?q=avarua&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 13 of Set 2 | avarua
# http://api.openweathermap.org/data/2.5/weather?q=siyabuswa&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 14 of Set 2 | siyabuswa
# http://api.openweathermap.org/data/2.5/weather?q=havoysund&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 15 of Set 2 | havoysund
# http://api.openweathermap.org/data/2.5/weather?q=asau&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 16 of Set 2 | asau
# http://api.openweathermap.org/data/2.5/weather?q=saskylakh&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 17 of Set 2 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?q=puerto ayora&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 18 of Set 2 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?q=vorukh&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 19 of Set 2 | vorukh
# http://api.openweathermap.org/data/2.5/weather?q=victoria&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 20 of Set 2 | victoria
# http://api.openweathermap.org/data/2.5/weather?q=chuy&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 21 of Set 2 | chuy
# http://api.openweathermap.org/data/2.5/weather?q=provideniya&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 22 of Set 2 | provideniya
# http://api.openweathermap.org/data/2.5/weather?q=broome&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 23 of Set 2 | broome
# http://api.openweathermap.org/data/2.5/weather?q=christchurch&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 24 of Set 2 | christchurch
# http://api.openweathermap.org/data/2.5/weather?q=ishigaki&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 25 of Set 2 | ishigaki
# http://api.openweathermap.org/data/2.5/weather?q=bethel&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 26 of Set 2 | bethel
# http://api.openweathermap.org/data/2.5/weather?q=davidson&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 27 of Set 2 | davidson
# http://api.openweathermap.org/data/2.5/weather?q=altamira&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 28 of Set 2 | altamira
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=poum&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 30 of Set 2 | poum
# http://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 31 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=alyangula&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 32 of Set 2 | alyangula
# http://api.openweathermap.org/data/2.5/weather?q=svetlyy&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 33 of Set 2 | svetlyy
# http://api.openweathermap.org/data/2.5/weather?q=bay saint louis&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 34 of Set 2 | bay saint louis
# http://api.openweathermap.org/data/2.5/weather?q=chokurdakh&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 35 of Set 2 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?q=sao joao da barra&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 36 of Set 2 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?q=louisbourg&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 37 of Set 2 | louisbourg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=mount gambier&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 38 of Set 2 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?q=invermere&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 39 of Set 2 | invermere
# http://api.openweathermap.org/data/2.5/weather?q=lipin bor&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 40 of Set 2 | lipin bor
# http://api.openweathermap.org/data/2.5/weather?q=ugoofaaru&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 41 of Set 2 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?q=mackay&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 42 of Set 2 | mackay
# http://api.openweathermap.org/data/2.5/weather?q=san quintin&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 43 of Set 2 | san quintin
# http://api.openweathermap.org/data/2.5/weather?q=knysna&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 44 of Set 2 | knysna
# http://api.openweathermap.org/data/2.5/weather?q=hokitika&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 45 of Set 2 | hokitika
# http://api.openweathermap.org/data/2.5/weather?q=mazyr&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 46 of Set 2 | mazyr
# http://api.openweathermap.org/data/2.5/weather?q=tiksi&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 47 of Set 2 | tiksi
# http://api.openweathermap.org/data/2.5/weather?q=esperance&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 48 of Set 2 | esperance
# http://api.openweathermap.org/data/2.5/weather?q=guerrero negro&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 49 of Set 2 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?q=sao cristovao&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 0 of Set 3 | sao cristovao
# http://api.openweathermap.org/data/2.5/weather?q=espanola&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 1 of Set 3 | espanola
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 2 of Set 3 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?q=linfen&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 3 of Set 3 | linfen
# http://api.openweathermap.org/data/2.5/weather?q=butaritari&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 4 of Set 3 | butaritari
# http://api.openweathermap.org/data/2.5/weather?q=sacuieu&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 5 of Set 3 | sacuieu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=aripuana&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 6 of Set 3 | aripuana
# http://api.openweathermap.org/data/2.5/weather?q=omsukchan&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 7 of Set 3 | omsukchan
# http://api.openweathermap.org/data/2.5/weather?q=sitka&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 8 of Set 3 | sitka
# http://api.openweathermap.org/data/2.5/weather?q=luwuk&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 9 of Set 3 | luwuk
# http://api.openweathermap.org/data/2.5/weather?q=samusu&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 10 of Set 3 | samusu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=hiriyur&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 11 of Set 3 | hiriyur
# http://api.openweathermap.org/data/2.5/weather?q=atuona&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 12 of Set 3 | atuona
# http://api.openweathermap.org/data/2.5/weather?q=marcona&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 13 of Set 3 | marcona
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=numan&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 14 of Set 3 | numan
# http://api.openweathermap.org/data/2.5/weather?q=lewistown&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 15 of Set 3 | lewistown
# http://api.openweathermap.org/data/2.5/weather?q=mendahara&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 16 of Set 3 | mendahara
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=dikson&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 17 of Set 3 | dikson
# http://api.openweathermap.org/data/2.5/weather?q=port blair&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 18 of Set 3 | port blair
# http://api.openweathermap.org/data/2.5/weather?q=gilgil&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 19 of Set 3 | gilgil
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=mitsamiouli&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 20 of Set 3 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 21 of Set 3 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?q=bambous virieux&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 22 of Set 3 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?q=mar del plata&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 23 of Set 3 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?q=hobart&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 24 of Set 3 | hobart
# http://api.openweathermap.org/data/2.5/weather?q=hede&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 25 of Set 3 | hede
# http://api.openweathermap.org/data/2.5/weather?q=husavik&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 26 of Set 3 | husavik
# http://api.openweathermap.org/data/2.5/weather?q=longyearbyen&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 27 of Set 3 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 28 of Set 3 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?q=eureka&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 29 of Set 3 | eureka
# http://api.openweathermap.org/data/2.5/weather?q=dumka&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 30 of Set 3 | dumka
# http://api.openweathermap.org/data/2.5/weather?q=caucaia&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 31 of Set 3 | caucaia
# http://api.openweathermap.org/data/2.5/weather?q=zhigansk&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 32 of Set 3 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?q=ribeira grande&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 33 of Set 3 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?q=tual&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 34 of Set 3 | tual
# http://api.openweathermap.org/data/2.5/weather?q=sabang&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 35 of Set 3 | sabang
# http://api.openweathermap.org/data/2.5/weather?q=torbay&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 36 of Set 3 | torbay
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 37 of Set 3 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?q=shakawe&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 38 of Set 3 | shakawe
# http://api.openweathermap.org/data/2.5/weather?q=gamba&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 39 of Set 3 | gamba
# http://api.openweathermap.org/data/2.5/weather?q=kainantu&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 40 of Set 3 | kainantu
# http://api.openweathermap.org/data/2.5/weather?q=itaituba&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 41 of Set 3 | itaituba
# http://api.openweathermap.org/data/2.5/weather?q=velikovechnoye&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 42 of Set 3 | velikovechnoye
# http://api.openweathermap.org/data/2.5/weather?q=pisco&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 43 of Set 3 | pisco
# http://api.openweathermap.org/data/2.5/weather?q=baykit&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 44 of Set 3 | baykit
# http://api.openweathermap.org/data/2.5/weather?q=margate&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 45 of Set 3 | margate
# http://api.openweathermap.org/data/2.5/weather?q=asfi&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 46 of Set 3 | asfi
# http://api.openweathermap.org/data/2.5/weather?q=dongkan&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 47 of Set 3 | dongkan
# http://api.openweathermap.org/data/2.5/weather?q=niquelandia&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 48 of Set 3 | niquelandia
# http://api.openweathermap.org/data/2.5/weather?q=khuzhir&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 49 of Set 3 | khuzhir
# http://api.openweathermap.org/data/2.5/weather?q=price&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 0 of Set 4 | price
# http://api.openweathermap.org/data/2.5/weather?q=teguise&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 1 of Set 4 | teguise
# http://api.openweathermap.org/data/2.5/weather?q=saleaula&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 2 of Set 4 | saleaula
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=aklavik&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 3 of Set 4 | aklavik
# http://api.openweathermap.org/data/2.5/weather?q=vega de alatorre&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 4 of Set 4 | vega de alatorre
# http://api.openweathermap.org/data/2.5/weather?q=portland&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 5 of Set 4 | portland
# http://api.openweathermap.org/data/2.5/weather?q=barrow&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 6 of Set 4 | barrow
# http://api.openweathermap.org/data/2.5/weather?q=cidreira&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 7 of Set 4 | cidreira
# http://api.openweathermap.org/data/2.5/weather?q=rocha&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 8 of Set 4 | rocha
# http://api.openweathermap.org/data/2.5/weather?q=gjusvik&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 9 of Set 4 | gjusvik
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=luderitz&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 10 of Set 4 | luderitz
# http://api.openweathermap.org/data/2.5/weather?q=ambon&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 11 of Set 4 | ambon
# http://api.openweathermap.org/data/2.5/weather?q=kodiak&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 12 of Set 4 | kodiak
# http://api.openweathermap.org/data/2.5/weather?q=pangoa&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 13 of Set 4 | pangoa
# http://api.openweathermap.org/data/2.5/weather?q=barentsburg&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 14 of Set 4 | barentsburg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=doka&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 15 of Set 4 | doka
# http://api.openweathermap.org/data/2.5/weather?q=coihaique&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 16 of Set 4 | coihaique
# http://api.openweathermap.org/data/2.5/weather?q=sorland&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 17 of Set 4 | sorland
# http://api.openweathermap.org/data/2.5/weather?q=souillac&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 18 of Set 4 | souillac
# http://api.openweathermap.org/data/2.5/weather?q=codrington&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 19 of Set 4 | codrington
# http://api.openweathermap.org/data/2.5/weather?q=lyuban&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 20 of Set 4 | lyuban
# http://api.openweathermap.org/data/2.5/weather?q=sola&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 21 of Set 4 | sola
# http://api.openweathermap.org/data/2.5/weather?q=high level&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 22 of Set 4 | high level
# http://api.openweathermap.org/data/2.5/weather?q=talnakh&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 23 of Set 4 | talnakh
# http://api.openweathermap.org/data/2.5/weather?q=russkaya polyana&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 24 of Set 4 | russkaya polyana
# http://api.openweathermap.org/data/2.5/weather?q=nileshwar&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 25 of Set 4 | nileshwar
# http://api.openweathermap.org/data/2.5/weather?q=san remo&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 26 of Set 4 | san remo
# http://api.openweathermap.org/data/2.5/weather?q=avera&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 27 of Set 4 | avera
# http://api.openweathermap.org/data/2.5/weather?q=kristiinankaupunki&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 28 of Set 4 | kristiinankaupunki
# http://api.openweathermap.org/data/2.5/weather?q=thinadhoo&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 29 of Set 4 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?q=toliary&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 30 of Set 4 | toliary
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=richards bay&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 31 of Set 4 | richards bay
# http://api.openweathermap.org/data/2.5/weather?q=sahrak&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 32 of Set 4 | sahrak
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=bolungarvik&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 33 of Set 4 | bolungarvik
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=lata&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 34 of Set 4 | lata
# http://api.openweathermap.org/data/2.5/weather?q=labuhan&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 35 of Set 4 | labuhan
# http://api.openweathermap.org/data/2.5/weather?q=soyo&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 36 of Set 4 | soyo
# http://api.openweathermap.org/data/2.5/weather?q=sept-iles&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 37 of Set 4 | sept-iles
# http://api.openweathermap.org/data/2.5/weather?q=arys&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 38 of Set 4 | arys
# http://api.openweathermap.org/data/2.5/weather?q=clyde river&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 39 of Set 4 | clyde river
# http://api.openweathermap.org/data/2.5/weather?q=krasnoselkup&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 40 of Set 4 | krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?q=eyl&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 41 of Set 4 | eyl
# http://api.openweathermap.org/data/2.5/weather?q=sao jose da coroa grande&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 42 of Set 4 | sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?q=ancud&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 43 of Set 4 | ancud
# http://api.openweathermap.org/data/2.5/weather?q=inuvik&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 44 of Set 4 | inuvik
# http://api.openweathermap.org/data/2.5/weather?q=ixtapa&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 45 of Set 4 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?q=macas&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 46 of Set 4 | macas
# http://api.openweathermap.org/data/2.5/weather?q=sistranda&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 47 of Set 4 | sistranda
# http://api.openweathermap.org/data/2.5/weather?q=tuatapere&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 48 of Set 4 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?q=vostok&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 49 of Set 4 | vostok
# http://api.openweathermap.org/data/2.5/weather?q=airai&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 0 of Set 5 | airai
# http://api.openweathermap.org/data/2.5/weather?q=bay roberts&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 1 of Set 5 | bay roberts
# http://api.openweathermap.org/data/2.5/weather?q=juxtlahuaca&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 2 of Set 5 | juxtlahuaca
# http://api.openweathermap.org/data/2.5/weather?q=bakchar&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 3 of Set 5 | bakchar
# http://api.openweathermap.org/data/2.5/weather?q=san agustin&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 4 of Set 5 | san agustin
# http://api.openweathermap.org/data/2.5/weather?q=camopi&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 5 of Set 5 | camopi
# http://api.openweathermap.org/data/2.5/weather?q=new norfolk&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 6 of Set 5 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?q=mugumu&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 7 of Set 5 | mugumu
# http://api.openweathermap.org/data/2.5/weather?q=ardakan&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 8 of Set 5 | ardakan
# http://api.openweathermap.org/data/2.5/weather?q=jumla&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 9 of Set 5 | jumla
# http://api.openweathermap.org/data/2.5/weather?q=buraydah&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 10 of Set 5 | buraydah
# http://api.openweathermap.org/data/2.5/weather?q=taiyuan&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 11 of Set 5 | taiyuan
# http://api.openweathermap.org/data/2.5/weather?q=athabasca&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 12 of Set 5 | athabasca
# http://api.openweathermap.org/data/2.5/weather?q=chernyshevskiy&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 13 of Set 5 | chernyshevskiy
# http://api.openweathermap.org/data/2.5/weather?q=hofn&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 14 of Set 5 | hofn
# http://api.openweathermap.org/data/2.5/weather?q=khammam&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 15 of Set 5 | khammam
# http://api.openweathermap.org/data/2.5/weather?q=pedernales&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 16 of Set 5 | pedernales
# http://api.openweathermap.org/data/2.5/weather?q=roald&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 17 of Set 5 | roald
# http://api.openweathermap.org/data/2.5/weather?q=amuntai&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 18 of Set 5 | amuntai
# http://api.openweathermap.org/data/2.5/weather?q=montrose&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 19 of Set 5 | montrose
# http://api.openweathermap.org/data/2.5/weather?q=shiyan&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 20 of Set 5 | shiyan
# http://api.openweathermap.org/data/2.5/weather?q=port elizabeth&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 21 of Set 5 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?q=vardo&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 22 of Set 5 | vardo
# http://api.openweathermap.org/data/2.5/weather?q=tevaitoa&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 23 of Set 5 | tevaitoa
# http://api.openweathermap.org/data/2.5/weather?q=srikakulam&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 24 of Set 5 | srikakulam
# http://api.openweathermap.org/data/2.5/weather?q=rio grande city&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 25 of Set 5 | rio grande city
# http://api.openweathermap.org/data/2.5/weather?q=ahipara&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 26 of Set 5 | ahipara
# http://api.openweathermap.org/data/2.5/weather?q=felidhoo&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 27 of Set 5 | felidhoo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=grafton&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 28 of Set 5 | grafton
# http://api.openweathermap.org/data/2.5/weather?q=syntul&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 29 of Set 5 | syntul
# http://api.openweathermap.org/data/2.5/weather?q=lompoc&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 30 of Set 5 | lompoc
# http://api.openweathermap.org/data/2.5/weather?q=fillmore&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 31 of Set 5 | fillmore
# http://api.openweathermap.org/data/2.5/weather?q=kawana waters&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 32 of Set 5 | kawana waters
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=korla&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 33 of Set 5 | korla
# http://api.openweathermap.org/data/2.5/weather?q=dovers&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 34 of Set 5 | dovers
# http://api.openweathermap.org/data/2.5/weather?q=ilulissat&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 35 of Set 5 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?q=lidkoping&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 36 of Set 5 | lidkoping
# http://api.openweathermap.org/data/2.5/weather?q=hobyo&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 37 of Set 5 | hobyo
# http://api.openweathermap.org/data/2.5/weather?q=grand gaube&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 38 of Set 5 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?q=vankleek hill&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 39 of Set 5 | vankleek hill
# http://api.openweathermap.org/data/2.5/weather?q=arraial do cabo&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 40 of Set 5 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?q=jamestown&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 41 of Set 5 | jamestown
# http://api.openweathermap.org/data/2.5/weather?q=bachaquero&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 42 of Set 5 | bachaquero
# http://api.openweathermap.org/data/2.5/weather?q=westport&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 43 of Set 5 | westport
# http://api.openweathermap.org/data/2.5/weather?q=eyrarbakki&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 44 of Set 5 | eyrarbakki
# http://api.openweathermap.org/data/2.5/weather?q=keetmanshoop&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 45 of Set 5 | keetmanshoop
# http://api.openweathermap.org/data/2.5/weather?q=sibolga&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 46 of Set 5 | sibolga
# http://api.openweathermap.org/data/2.5/weather?q=mawlaik&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 47 of Set 5 | mawlaik
# http://api.openweathermap.org/data/2.5/weather?q=lakes entrance&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 48 of Set 5 | lakes entrance
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 49 of Set 5 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?q=saldanha&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 0 of Set 6 | saldanha
# http://api.openweathermap.org/data/2.5/weather?q=banmo&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 1 of Set 6 | banmo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=cabo san lucas&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 2 of Set 6 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?q=zhongshu&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 3 of Set 6 | zhongshu
# http://api.openweathermap.org/data/2.5/weather?q=puerto escondido&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 4 of Set 6 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?q=bacuit&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 5 of Set 6 | bacuit
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=obluche&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 6 of Set 6 | obluche
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=cherskiy&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 7 of Set 6 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?q=padang&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 8 of Set 6 | padang
# http://api.openweathermap.org/data/2.5/weather?q=kingsville&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 9 of Set 6 | kingsville
# http://api.openweathermap.org/data/2.5/weather?q=lujan&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 10 of Set 6 | lujan
# http://api.openweathermap.org/data/2.5/weather?q=altay&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 11 of Set 6 | altay
# http://api.openweathermap.org/data/2.5/weather?q=cabedelo&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 12 of Set 6 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?q=takoradi&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 13 of Set 6 | takoradi
# http://api.openweathermap.org/data/2.5/weather?q=zhuhai&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 14 of Set 6 | zhuhai
# http://api.openweathermap.org/data/2.5/weather?q=castro&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 15 of Set 6 | castro
# http://api.openweathermap.org/data/2.5/weather?q=rio grande&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 16 of Set 6 | rio grande
# http://api.openweathermap.org/data/2.5/weather?q=kununurra&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 17 of Set 6 | kununurra
# http://api.openweathermap.org/data/2.5/weather?q=tulagi&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 18 of Set 6 | tulagi
# http://api.openweathermap.org/data/2.5/weather?q=yar-sale&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 19 of Set 6 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?q=fevralsk&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 20 of Set 6 | fevralsk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=yuci&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 21 of Set 6 | yuci
# http://api.openweathermap.org/data/2.5/weather?q=youhao&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 22 of Set 6 | youhao
# http://api.openweathermap.org/data/2.5/weather?q=vao&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 23 of Set 6 | vao
# http://api.openweathermap.org/data/2.5/weather?q=tura&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 24 of Set 6 | tura
# http://api.openweathermap.org/data/2.5/weather?q=quatre cocos&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 25 of Set 6 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 26 of Set 6 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?q=gotsu&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 27 of Set 6 | gotsu
# http://api.openweathermap.org/data/2.5/weather?q=sicamous&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 28 of Set 6 | sicamous
# http://api.openweathermap.org/data/2.5/weather?q=sorvag&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 29 of Set 6 | sorvag
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=taksimo&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 30 of Set 6 | taksimo
# http://api.openweathermap.org/data/2.5/weather?q=upernavik&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 31 of Set 6 | upernavik
# http://api.openweathermap.org/data/2.5/weather?q=arona&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 32 of Set 6 | arona
# http://api.openweathermap.org/data/2.5/weather?q=kaitangata&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 33 of Set 6 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?q=novikovo&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 34 of Set 6 | novikovo
# http://api.openweathermap.org/data/2.5/weather?q=faya&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 35 of Set 6 | faya
# http://api.openweathermap.org/data/2.5/weather?q=alekseyevsk&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 36 of Set 6 | alekseyevsk
# http://api.openweathermap.org/data/2.5/weather?q=higuey&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 37 of Set 6 | higuey
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=banda aceh&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 38 of Set 6 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?q=sentyabrskiy&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 39 of Set 6 | sentyabrskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=ust-koksa&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 40 of Set 6 | ust-koksa
# http://api.openweathermap.org/data/2.5/weather?q=rosarito&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 41 of Set 6 | rosarito
# http://api.openweathermap.org/data/2.5/weather?q=boa esperanca&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 42 of Set 6 | boa esperanca
# http://api.openweathermap.org/data/2.5/weather?q=amapa&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 43 of Set 6 | amapa
# http://api.openweathermap.org/data/2.5/weather?q=namatanai&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 44 of Set 6 | namatanai
# http://api.openweathermap.org/data/2.5/weather?q=caohai&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 45 of Set 6 | caohai
# http://api.openweathermap.org/data/2.5/weather?q=utiroa&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 46 of Set 6 | utiroa
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=abha&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 47 of Set 6 | abha
# http://api.openweathermap.org/data/2.5/weather?q=thompson&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 48 of Set 6 | thompson
# http://api.openweathermap.org/data/2.5/weather?q=la ronge&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 49 of Set 6 | la ronge
# http://api.openweathermap.org/data/2.5/weather?q=maloy&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 0 of Set 7 | maloy
# http://api.openweathermap.org/data/2.5/weather?q=harda&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 1 of Set 7 | harda
# http://api.openweathermap.org/data/2.5/weather?q=viligili&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 2 of Set 7 | viligili
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=itoman&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 3 of Set 7 | itoman
# http://api.openweathermap.org/data/2.5/weather?q=meulaboh&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 4 of Set 7 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?q=ayan&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 5 of Set 7 | ayan
# http://api.openweathermap.org/data/2.5/weather?q=anloga&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 6 of Set 7 | anloga
# http://api.openweathermap.org/data/2.5/weather?q=necochea&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 7 of Set 7 | necochea
# http://api.openweathermap.org/data/2.5/weather?q=kokopo&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 8 of Set 7 | kokopo
# http://api.openweathermap.org/data/2.5/weather?q=watsa&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 9 of Set 7 | watsa
# http://api.openweathermap.org/data/2.5/weather?q=mizdah&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# ...
# Processing Record 43 of Set 10 | jiazi
# http://api.openweathermap.org/data/2.5/weather?q=te anau&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 44 of Set 10 | te anau
# http://api.openweathermap.org/data/2.5/weather?q=chama&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 45 of Set 10 | chama
# http://api.openweathermap.org/data/2.5/weather?q=huittinen&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 46 of Set 10 | huittinen
# http://api.openweathermap.org/data/2.5/weather?q=port hawkesbury&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 47 of Set 10 | port hawkesbury
# http://api.openweathermap.org/data/2.5/weather?q=ust-ilimsk&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 48 of Set 10 | ust-ilimsk
# http://api.openweathermap.org/data/2.5/weather?q=cayenne&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 49 of Set 10 | cayenne
# http://api.openweathermap.org/data/2.5/weather?q=wakkanai&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 0 of Set 11 | wakkanai
# http://api.openweathermap.org/data/2.5/weather?q=sorong&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 1 of Set 11 | sorong
# http://api.openweathermap.org/data/2.5/weather?q=sao joao nepomuceno&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 2 of Set 11 | sao joao nepomuceno
# http://api.openweathermap.org/data/2.5/weather?q=atambua&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 3 of Set 11 | atambua
# http://api.openweathermap.org/data/2.5/weather?q=yamada&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 4 of Set 11 | yamada
# http://api.openweathermap.org/data/2.5/weather?q=grave&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 5 of Set 11 | grave
# http://api.openweathermap.org/data/2.5/weather?q=wanning&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 6 of Set 11 | wanning
# http://api.openweathermap.org/data/2.5/weather?q=paucartambo&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 7 of Set 11 | paucartambo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=vanavara&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 8 of Set 11 | vanavara
# http://api.openweathermap.org/data/2.5/weather?q=itarema&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 9 of Set 11 | itarema
# http://api.openweathermap.org/data/2.5/weather?q=jacareacanga&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 10 of Set 11 | jacareacanga
# http://api.openweathermap.org/data/2.5/weather?q=inirida&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 11 of Set 11 | inirida
# http://api.openweathermap.org/data/2.5/weather?q=girua&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 12 of Set 11 | girua
# http://api.openweathermap.org/data/2.5/weather?q=anori&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 13 of Set 11 | anori
# http://api.openweathermap.org/data/2.5/weather?q=krasnyy yar&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 14 of Set 11 | krasnyy yar
# http://api.openweathermap.org/data/2.5/weather?q=douglas&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 15 of Set 11 | douglas
# http://api.openweathermap.org/data/2.5/weather?q=yorosso&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 16 of Set 11 | yorosso
# http://api.openweathermap.org/data/2.5/weather?q=andenes&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 17 of Set 11 | andenes
# http://api.openweathermap.org/data/2.5/weather?q=uarini&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 18 of Set 11 | uarini
# http://api.openweathermap.org/data/2.5/weather?q=slave lake&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 19 of Set 11 | slave lake
# http://api.openweathermap.org/data/2.5/weather?q=oranmore&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 20 of Set 11 | oranmore
# http://api.openweathermap.org/data/2.5/weather?q=pevek&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 21 of Set 11 | pevek
# http://api.openweathermap.org/data/2.5/weather?q=comodoro rivadavia&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 22 of Set 11 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?q=seabra&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 23 of Set 11 | seabra
# http://api.openweathermap.org/data/2.5/weather?q=arlit&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 24 of Set 11 | arlit
# http://api.openweathermap.org/data/2.5/weather?q=laguna&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 25 of Set 11 | laguna
# http://api.openweathermap.org/data/2.5/weather?q=matagami&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 26 of Set 11 | matagami
# http://api.openweathermap.org/data/2.5/weather?q=santa isabel do rio negro&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 27 of Set 11 | santa isabel do rio negro
# http://api.openweathermap.org/data/2.5/weather?q=erzin&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 28 of Set 11 | erzin
# http://api.openweathermap.org/data/2.5/weather?q=ban nahin&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 29 of Set 11 | ban nahin
# http://api.openweathermap.org/data/2.5/weather?q=mahon&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 30 of Set 11 | mahon
# http://api.openweathermap.org/data/2.5/weather?q=miramar&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 31 of Set 11 | miramar
# http://api.openweathermap.org/data/2.5/weather?q=ndola&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 32 of Set 11 | ndola
# http://api.openweathermap.org/data/2.5/weather?q=challans&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 33 of Set 11 | challans
# http://api.openweathermap.org/data/2.5/weather?q=coahuayana&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 34 of Set 11 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?q=kamphaeng phet&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 35 of Set 11 | kamphaeng phet
# http://api.openweathermap.org/data/2.5/weather?q=ostrovnoy&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 36 of Set 11 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?q=huoqiu&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 37 of Set 11 | huoqiu
# http://api.openweathermap.org/data/2.5/weather?q=hambantota&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 38 of Set 11 | hambantota
# http://api.openweathermap.org/data/2.5/weather?q=paita&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 39 of Set 11 | paita
# http://api.openweathermap.org/data/2.5/weather?q=mantua&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 40 of Set 11 | mantua
# http://api.openweathermap.org/data/2.5/weather?q=nemuro&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 41 of Set 11 | nemuro
# http://api.openweathermap.org/data/2.5/weather?q=khandbari&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 42 of Set 11 | khandbari
# http://api.openweathermap.org/data/2.5/weather?q=chicama&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 43 of Set 11 | chicama
# http://api.openweathermap.org/data/2.5/weather?q=mount isa&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 44 of Set 11 | mount isa
# http://api.openweathermap.org/data/2.5/weather?q=badvel&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 45 of Set 11 | badvel
# http://api.openweathermap.org/data/2.5/weather?q=mkushi&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 46 of Set 11 | mkushi
# http://api.openweathermap.org/data/2.5/weather?q=grindavik&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 47 of Set 11 | grindavik
# http://api.openweathermap.org/data/2.5/weather?q=sobolevo&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 48 of Set 11 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?q=shimoda&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 49 of Set 11 | shimoda
# http://api.openweathermap.org/data/2.5/weather?q=huarmey&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 0 of Set 12 | huarmey
# http://api.openweathermap.org/data/2.5/weather?q=sumenep&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 1 of Set 12 | sumenep
# http://api.openweathermap.org/data/2.5/weather?q=san cristobal&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 2 of Set 12 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?q=nyurba&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 3 of Set 12 | nyurba
# http://api.openweathermap.org/data/2.5/weather?q=pangnirtung&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 4 of Set 12 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?q=poya&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 5 of Set 12 | poya
# http://api.openweathermap.org/data/2.5/weather?q=jabiru&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 6 of Set 12 | jabiru
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=kolokani&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 7 of Set 12 | kolokani
# http://api.openweathermap.org/data/2.5/weather?q=petrolandia&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 8 of Set 12 | petrolandia
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=rawannawi&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 9 of Set 12 | rawannawi
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=lappeenranta&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 10 of Set 12 | lappeenranta
# http://api.openweathermap.org/data/2.5/weather?q=mangai&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 11 of Set 12 | mangai
# http://api.openweathermap.org/data/2.5/weather?q=jaciara&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 12 of Set 12 | jaciara
# http://api.openweathermap.org/data/2.5/weather?q=saquarema&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 13 of Set 12 | saquarema
# http://api.openweathermap.org/data/2.5/weather?q=ha tinh&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 14 of Set 12 | ha tinh
# http://api.openweathermap.org/data/2.5/weather?q=shenzhen&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 15 of Set 12 | shenzhen
# http://api.openweathermap.org/data/2.5/weather?q=novooleksiyivka&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 16 of Set 12 | novooleksiyivka
# http://api.openweathermap.org/data/2.5/weather?q=banjar&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 17 of Set 12 | banjar
# http://api.openweathermap.org/data/2.5/weather?q=egvekinot&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 18 of Set 12 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?q=yumen&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 19 of Set 12 | yumen
# http://api.openweathermap.org/data/2.5/weather?q=meyungs&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 20 of Set 12 | meyungs
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?q=auki&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 21 of Set 12 | auki
# http://api.openweathermap.org/data/2.5/weather?q=hailar&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 22 of Set 12 | hailar
# http://api.openweathermap.org/data/2.5/weather?q=amiens&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 23 of Set 12 | amiens
# http://api.openweathermap.org/data/2.5/weather?q=nishihara&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 24 of Set 12 | nishihara
# http://api.openweathermap.org/data/2.5/weather?q=lukulu&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 25 of Set 12 | lukulu
# http://api.openweathermap.org/data/2.5/weather?q=college&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 26 of Set 12 | college
# http://api.openweathermap.org/data/2.5/weather?q=hami&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 27 of Set 12 | hami
# http://api.openweathermap.org/data/2.5/weather?q=ustynivka&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 28 of Set 12 | ustynivka
# http://api.openweathermap.org/data/2.5/weather?q=oranjemund&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 29 of Set 12 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?q=beaupre&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 30 of Set 12 | beaupre
# http://api.openweathermap.org/data/2.5/weather?q=puqi&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 31 of Set 12 | puqi
# http://api.openweathermap.org/data/2.5/weather?q=adrar&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 32 of Set 12 | adrar
# http://api.openweathermap.org/data/2.5/weather?q=ojinaga&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 33 of Set 12 | ojinaga
# http://api.openweathermap.org/data/2.5/weather?q=parkersburg&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 34 of Set 12 | parkersburg
# http://api.openweathermap.org/data/2.5/weather?q=carutapera&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 35 of Set 12 | carutapera
# http://api.openweathermap.org/data/2.5/weather?q=vila velha&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 36 of Set 12 | vila velha
# http://api.openweathermap.org/data/2.5/weather?q=ranfurly&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 37 of Set 12 | ranfurly
# http://api.openweathermap.org/data/2.5/weather?q=sarangani&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 38 of Set 12 | sarangani
# http://api.openweathermap.org/data/2.5/weather?q=diveyevo&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 39 of Set 12 | diveyevo
# http://api.openweathermap.org/data/2.5/weather?q=los llanos de aridane&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 40 of Set 12 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?q=senanga&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 41 of Set 12 | senanga
# http://api.openweathermap.org/data/2.5/weather?q=sao filipe&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 42 of Set 12 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?q=ygatimi&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 43 of Set 12 | ygatimi
# http://api.openweathermap.org/data/2.5/weather?q=nsanje&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 44 of Set 12 | nsanje
# http://api.openweathermap.org/data/2.5/weather?q=rybinsk&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 45 of Set 12 | rybinsk
# http://api.openweathermap.org/data/2.5/weather?q=ostersund&appid=7a377ca36b94f99bc3a054d1b400cdc0&units=Metric
# Processing Record 46 of Set 12 | ostersund
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          540
# Lat           540
# Lng           540
# Max Temp      540
# Humidity      540
# Cloudiness    540
# Wind Speed    540
# Country       540
# Date          540
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   bagotville -28.9833  153.4167     22.58        84         100        1.80
# 1      ushuaia -54.8000  -68.3000      1.81        93         100       10.29
# 2  port alfred -33.5906   26.8910     16.21        78          98        1.79
# 3       albany  42.6001  -73.9662      8.49        53         100        1.34
# 4     upornaya  44.3914   41.0196      6.48        90          52        2.82
#
#   Country        Date
# 0      AU  1679954859
# 1      AR  1679954860
# 2      ZA  1679954860
# 3      US  1679954860
# 4      RU  1679954860

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         bagotville -28.9833  153.4167     22.58        84         100
# 1            ushuaia -54.8000  -68.3000      1.81        93         100
# 2        port alfred -33.5906   26.8910     16.21        78          98
# 3             albany  42.6001  -73.9662      8.49        53         100
# 4           upornaya  44.3914   41.0196      6.48        90          52
#
#          Wind Speed Country        Date
# City_ID
# 0              1.80      AU  1679954859
# 1             10.29      AR  1679954860
# 2              1.79      ZA  1679954860
# 3              1.34      US  1679954860
# 4              2.82      RU  1679954860

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", edgecolor="black",color="blue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature([Date])")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.xlim(min(city_data_df["Lat"])-10, max(city_data_df["Lat"])+10)
plt.ylim(min(city_data_df["Max Temp"])-5, max(city_data_df["Max Temp"])+5)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", edgecolor="black",color="blue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity([Date])")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.xlim(min(city_data_df["Lat"])-10, max(city_data_df["Lat"])+10)
plt.ylim(min(city_data_df["Humidity"])-10, max(city_data_df["Humidity"])+10)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", edgecolor="black",color="blue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness([Date])")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.xlim(min(city_data_df["Lat"])-10, max(city_data_df["Lat"])+10)
plt.ylim(min(city_data_df["Cloudiness"])-10, max(city_data_df["Cloudiness"])+10)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", edgecolor="black",color="blue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed([Date])")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.xlim(min(city_data_df["Lat"])-10, max(city_data_df["Lat"])+10)
plt.ylim(min(city_data_df["Wind Speed"])-2, max(city_data_df["Wind Speed"])+2)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
def plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates):
    
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    
    # Create scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot regression line
    plt.plot(x_values, regress_values, "r")
    
    # Annotate plot
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.annotate(f"y = {round(slope,2)}x + {round(intercept,2)}\nr = {round(rvalue,2)}", text_coordinates, fontsize=15, color="red")
    
    # Show plot
    plt.show() 

# Call the function to plot the Northern Hemisphere data
x_values = northern_df["Lat"]
y_values = northern_df["Max Temp"]
xlabel = "Latitude"
ylabel = "Max Temp"
title = "City Latitude vs. Max Temperature"
text_coordinates = (5, -10)
plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates)

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
